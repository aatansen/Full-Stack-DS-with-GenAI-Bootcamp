# %% [markdown]
# ## Strings in Python

# %% [markdown]
# ### String is a sequence of characters enclosed in quotes
#
# #### In Python specifically, strings are a sequence of Unicode Characters
#
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Functions

# %% [markdown]
# ### Creating Strings

# %%
s = 'hello'
s = "hello"

# multiline strings
s = '''hello'''
s = """hello"""
s = str('hello')
print(s)
# Out:
# hello

# %% [markdown]
# #### String explicit type conversion (int to str)

# %%
a = 34
str(a)
# Out:
# '34'

# %%
text = 'it's my bike'
print(text)
# Out:
#   Cell In[3], line 1
#     text = 'it's my bike'
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
text = "it's my bike"
print(text)
# Out:
# it's my bike

# %% [markdown]
# ### Accessing Strings

# %%
# positive access

s = "welcome to python"

# %%
print(s[0])
# Out:
# w

# %%
print(s[11])
# Out:
# p

# %%
print(s[50])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(s[50])
#
# IndexError: string index out of range

# %%
len(s)
# Out:
# 17

# %%
# Negative indexing

s = "welcome to python"

# %%
print(s[-11])
# Out:
# e

# %%
# String slicing

s = "welcome to python"

# %%
s[0:7]
# Out:
# 'welcome'

# %%
print(s[11:17])
# Out:
# python

# %%
print(s[11:500])
# Out:
# python

# %%
print(s[11:])
# Out:
# python

# %%
print(s[:])
# Out:
# welcome to python

# %%
print(s[0:7:2])
# Out:
# wloe

# %%
s = "welcome to python"

# %%
print(s[1:7])
# Out:
# elcome

# %%
print(s[6::-1])
# Out:
# emoclew

# %%
print(s[6::-2])
# Out:
# eolw

# %%
s
# Out:
# 'welcome to python'

# %%
print(s[::-1])
# Out:
# nohtyp ot emoclew

# %%
print(s[::-2])
# Out:
# nhy teolw

# %% [markdown]
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings

# %%
s = "welcome to python"

# %%
s[0] = "A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 s[0] = "A"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Python strings are immutable

# %%
s[18] = "A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s[18] = "A"
#
# TypeError: 'str' object does not support item assignment

# %%
del s[0]
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[42], line 1
#
# ----> 1 del s[0]
#
#
#
# TypeError: 'str' object doesn't support item deletion

# %%
del s

# %%
s
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[44], line 1
#
# ----> 1 s
#
#
#
# NameError: name 's' is not defined

# %% [markdown]
# ### Index access

# %%
intro = "My name is Tansen"
intro.index("T") - len(intro)
# Out:
# -6

# %%
intro[-6::]
# Out:
# 'Tansen'

# %% [markdown]
# ### positive and negative index access (Multiple)

# %%
indices  = [i for i,c in enumerate(intro) if c =="n"]
indices
# Out:
# [3, 13, 16]

# %%
neg_indices = [i - len(intro) for i in indices]
neg_indices
# Out:
# [-14, -4, -1]

# %%
s="welcome to python"

indices = [i for i,c in enumerate(s) if c=="n"]
indices
# Out:
# [16]

# %% [markdown]
# ## Operations on Strings
#
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
# Arithmetic Operations

print("Hi" + " " + "Everyone") #concatination
# Out:
# Hi Everyone

# %%
print("Hi" * 500)
# Out:
# ...

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %%
# Relational Operations

print("Hello" == "Hello") # equality
print("Hello"!= "World") # not equal
print("Hello" > "Hi") # greater than
print("Hello" < "World") # less than
print("Hello" >= "Hello") # greater than or equal to
# Out:
# True
# True
# False
# True
# True

# %%
# Logical Operations

"hello" and "World"
# Out:
# 'World'

# %%
"hello" or 'world'
# Out:
# 'hello'

# %%
not "hello"
# Out:
# False

# %%
# Loops on Strings
for i in "Tansen":
    print(i)
# Out:
# T
# a
# n
# s
# e
# n

# %%
# Membership Operations

'B' in "Tansen"
# Out:
# False

# %% [markdown]
# ## Common Functions/Methods
# - len
# - max
# - min
# - sorted

# %%
s = "Welcome to Python"

# %%
len(s)
# Out:
# 17

# %%
max(s)
# Out:
# 'y'

# %%
min(s)
# Out:
# ' '

# %%
s
# Out:
# 'Welcome to Python'

# %%
sorted(s)
# Out:
# [' ',
#  ' ',
#  'P',
#  'W',
#  'c',
#  'e',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  't',
#  't',
#  'y']

# %%
sorted(s, reverse=True)
# Out:
# ['y',
#  't',
#  't',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  'W',
#  'P',
#  ' ',
#  ' ']

# %% [markdown]
# ## Strings Functions/Methods
# - Capitalize
# - Title
# - Upper
# - Lower
# - Swapcase

# %%
s = "welcome to python"

# %%
s.capitalize()
# Out:
# 'Welcome to python'

# %%
print(s)
# Out:
# welcome to python

# %%
s.title()
# Out:
# 'Welcome To Python'

# %%
s.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
s = 'WELCOME TO PYTHON'

# %%
s.lower()
# Out:
# 'welcome to python'

# %%
s = 'wElCoMe'

# %%
s.swapcase()
# Out:
# 'WeLcOmE'

# %% [markdown]
# - Count
# - Find
# - Index

# %%
s = "My name is Tansen"

# %%
s.count("p")
# Out:
# 0

# %%
s.find("B")
# Out:
# -1

# %%
s.find("z")
# Out:
# -1

# %%
s.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 s.index("z")
#
# ValueError: substring not found

# %%
s.index("B")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 s.index("B")
#
# ValueError: substring not found

# %% [markdown]
# - endswith
# - startswith

# %%
s = "My name is Tansen"

# %%
s.endswith("py")
# Out:
# False

# %%
s.startswith("My")
# Out:
# True

# %% [markdown]
#  format

# %%
name = "Tansen"
gender = "Male"

s = "My name is {}, and I am a {}"

# %%
s.format(name, gender)
# Out:
# 'My name is Tansen, and I am a Male'

# %%
s = "Welcome {} to facebook"

# %%
name = "Alex"

s.format(name)
# Out:
# 'Welcome Alex to facebook'

# %%
name = "Tansen"
gender = "Male"

s = "My name is {1}, and I am a {0}"

# %%
s.format(name, gender)
# Out:
# 'My name is Male, and I am a Tansen'

# %%
s.format(gender, name)
# Out:
# 'My name is Tansen, and I am a Male'

# %% [markdown]
# # f-strings

# %%
age = 25
s = f"My name is {name}, and I am a {gender}. I am {age} years old"
print(s)
# Out:
# My name is Tansen, and I am a Male. I am 25 years old

# %% [markdown]
# - isalnum
# - isalpha
# - isdigit
# - isidentifier

# %%
s = "Tansen123@"

# %%
s.isalnum()
# Out:
# False

# %%
s = "123"
s.isalnum()
# Out:
# True

# %%
s = "Tansen12"

# %%
s.isalpha()
# Out:
# False

# %%
s = "12"
s.isdigit()
# Out:
# True

# %%
s = "name_age"

# %%
s.isidentifier()
# Out:
# True

# %% [markdown]
# - Split
# - Join

# %%
s = "My name is Tansen"

# %%
s.split()
# Out:
# ['My', 'name', 'is', 'Tansen']

# %%
s = "My,name,is,Tansen"

# %%
s.split(",")
# Out:
# ['My', 'name', 'is', 'Tansen']

# %%
s = "My@name@is@Tansen"

# %%
r = s.split("@")

# %%
type(r)
# Out:
# list

# %%
# join

words = ['My', 'name', 'is', 'Tansen']

# %%
s = " "

s = s.join(words)
print(s)
# Out:
# My name is Tansen

# %% [markdown]
# - Replace
# - Strip

# %%
s = "My name is Tansen"

# %%
s.replace("Tansen", "Alex")
# Out:
# 'My name is Alex'

# %%
s
# Out:
# 'My name is Tansen'

# %%
s = "  My name is Tansen      "

# %%
s = s.strip()

# %%
s
# Out:
# 'My name is Tansen'

# %% [markdown]
# ## Strings Exercise

# %% [markdown]
# 1. Find the length of a given string without using the len() function
#
# 2. Extract username from a given email.
# - Ex:
#     if the email is aatansen@gmail.com
#     then the username should be aatansen

# %%
s = input("Enter a String: ")

counter = 1
for i in s:
    counter += 1


print(counter)
# Out:
# 9

# %%
len("My name is tansen")
# Out:
# 17

# %%
# email ="aatansen@gmail.com"
email = input("Enter your email: ")

pos = email.index("@")

print(email[0:pos])
# Out:
# aatansen

# %%
e = "tansen@gmail.com"
e.index("@")
# Out:
# 6

# %% [markdown]
# 3. Write a program that can check whether a given string is palindrome or not.
#
#  - abba
#  - mam
#  - madam

# %%
word = input("Enter your word: ")

flag = True

for i in range(0, len(word)//2):
    if word[i] != word[len(word) - i -1]:
        flag = False
        print("Not a Palindrome")
        break

if flag:
    print("Palindrome")
# Out:
# Palindrome

# %%
abba  = 4

# %%
4//2
# Out:
# 2

# %% [markdown]
# - ab ba
# - malayalam = 9
# - 9//2 = 4
# - mala y alam
