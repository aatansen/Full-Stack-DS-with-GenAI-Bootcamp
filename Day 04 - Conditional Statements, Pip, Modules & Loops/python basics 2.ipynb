# %%
print("OK")
# Out:
# OK

# %% [markdown]
# # Conditional Statements in Python

# %%
# Login Function demo - aatansen.com

"""
Actual Credentials:

Email: aatansen@gmail.com
Password: aatansen@12345
"""

email = input("Enter your email: ")
password = input("Enter your password: ")


actual_email = "aatansen@gmail.com"
actual_password = "aatansen@12345"

if email == actual_email and password == actual_password:
    print("Login Successfull!")

else:
    print("Invalid Credentials!")
# Out:
# Invalid Credentials!

# %%
# Login Function demo - aatansen.com

"""
Actual Credentials:

Email: aatansen@gmail.com
Password: aatansen@12345
"""

email = input("Enter your email: ")
password = input("Enter your password: ")


actual_email = "aatansen@gmail.com"
actual_password = "aatansen@12345"

if email == actual_email and password == actual_password:
    print("Login Successfull!")

elif email == actual_email and password != actual_password:
    print("Incorrect Password!")


else:
    print("Invalid Credentials!")
# Out:
# Invalid Credentials!

# %% [markdown]
# # Nasted Conditional Statements

# %%
# Login Function demo - aatansen.com

"""
Actual Credentials:

Email: aatansen@gmail.com
Password: aatansen@12345
"""

email = input("Enter your email: ")
password = input("Enter your password: ")


actual_email = "aatansen@gmail.com"
actual_password = "aatansen@12345"

if email == actual_email and password == actual_password:
    print("Login Successfull!")

elif email == actual_email and password != actual_password:
    print("Please try again!")
    password = input("Enter your password again: ")

    if password == actual_password:
        print("Success!")

    else:
        print("Wrong!")


else:
    print("Invalid Credentials!")
# Out:
# Login Successfull!

# %%
if condition:
    #write something

elif condition:
    #write something


else:
    #write something
# Out:
#   Cell In[5], line 4
#     elif condition:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# # Modules in Python
#
# 1. Builtins Module / Package
# 2. External Module / Package

# %% [markdown]
# https://docs.python.org/3/py-modindex.html

# %% [markdown]
# # Builtins Module / Package
# - math
# - keywords
# - random
# - datetime

# %%
import math

# %%
math.sqrt(200)
# Out:
# 14.142135623730951

# %%
math.factorial(4)
# Out:
# 24

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import random

print(random.randint(1,100))
# Out:
# 60

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2025-11-06 04:16:03.651655

# %% [markdown]
# ##### External Module / Package

# %%
# !pip install fastapi
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 9.6 MB/s  0:00:00
# ...
#
#    ------- --------------------------------  2/11 [idna]
#    ---------- -----------------------------  3/11 [annotated-types]
#    ------------------------- --------------  7/11 [anyio]
#    ------------------------- --------------  7/11 [anyio]
#    ------------------------- --------------  7/11 [anyio]
#    ------------------------- --------------  7/11 [anyio]
#    ----------------------------- ----------  8/11 [starlette]
#    ----------------------------- ----------  8/11 [starlette]
#    ----------------------------- ----------  8/11 [starlette]
#    -------------------------------- -------  9/11 [pydantic]
#    -------------------------------- -------  9/11 [pydantic]
#    -------------------------------- -------  9/11 [pydantic]
#    -------------------------------- -------  9/11 [pydantic]
# ...

# %%
# !pip uninstall fastapi -y
# Out:
# Found existing installation: fastapi 0.121.0
# Uninstalling fastapi-0.121.0:
#   Successfully uninstalled fastapi-0.121.0

# %%
# !pixi add fastapi
# Out:
# Added fastapi >=0.121.0,<0.122
