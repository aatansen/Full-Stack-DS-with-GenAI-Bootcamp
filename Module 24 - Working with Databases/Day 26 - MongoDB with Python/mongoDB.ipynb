# %%
print("Ok")
# Out:
# Ok

# %%
import pandas as pd

# %%
data = pd.read_csv("visa_db.csv")

# %%
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
data.shape
# Out:
# (25480, 12)

# %%
data.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data_dic = data.to_dict(orient='records')

# %%
len(data_dic)
# Out:
# 25480

# %%
from dotenv import load_dotenv
import os

load_dotenv()

DB_NAME = os.getenv("DB_NAME")
COLLECTION_NAME = os.getenv("COLLECTION_NAME")
CONNECTION_URL = os.getenv("CONNECTION_URL")

# %%
import pymongo

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %% [markdown]
# # Storing Data to MongoDB Database

# %%
rec = collection.insert_many(data_dic)

# %% [markdown]
# # Fetching Data from MongoDB Database

# %%
records = collection.find()

# %%
records

# %%
for i in records[:10]:
    print(i)
# Out:
# {'_id': ObjectId('69615560755b03f7f6fbe8c6'), 'case_id': 'EZYV01', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 14513, 'yr_of_estab': 2007, 'region_of_employment': 'West', 'prevailing_wage': 592.2029, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# {'_id': ObjectId('69615560755b03f7f6fbe8c7'), 'case_id': 'EZYV02', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2412, 'yr_of_estab': 2002, 'region_of_employment': 'Northeast', 'prevailing_wage': 83425.65, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# ...

# %%
df = pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  69615560755b03f7f6fbe8c6  EZYV01      Asia           High School
# 1  69615560755b03f7f6fbe8c7  EZYV02      Asia              Master's
# 2  69615560755b03f7f6fbe8c8  EZYV03      Asia            Bachelor's
# 3  69615560755b03f7f6fbe8c9  EZYV04      Asia            Bachelor's
# 4  69615560755b03f7f6fbe8ca  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...

# %%
if "_id" in df.columns:
    df.drop(columns=["_id"], inplace=True)

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# df.to_csv("MongoDB_Data.csv", index=False)

# %%
client.get_database("visa_database")
# Out:
# Database(MongoClient(host=['ac-y226ub1-shard-00-02.fqswcoa.mongodb.net:27017', 'ac-y226ub1-shard-00-01.fqswcoa.mongodb.net:27017', 'ac-y226ub1-shard-00-00.fqswcoa.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-24tonw-shard-0', tls=True), 'visa_database')
